# %% [markdown]
# # WIZELINE DATA ENGINEERING BOOTCAMP
# ## Code Challenge
# ### Adrian Ramos Perez

# %%
import pandas as pd
import numpy as np
url='https://drive.google.com/file/d/1PCJ7ltluquoXKi6MYTPMfwZQNI_-MIFP/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
data = pd.read_csv(url)

data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
answer_dict =  {"Q1" : None,
                "Q2" : None,
                "Q3" : None,
                "Q4" : None,
                "Q5" : None,
                "Q6" : None,
                "Q7" : None}
answer_dict
# Out:
# {'Q1': None,
#  'Q2': None,
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %% [markdown]
# ## Q1. What is the average CO2 emmission per gram/mile of all Volkswagen cars?
# #### Format: A floating number
# #### Example answer: answer_dict["Q1"] =  11.547

# %%
########## Q1
Volkswagen_cars = data[data['Make']=='Volkswagen']
Avg = Volkswagen_cars['CO2 Emission Grams/Mile'].mean()
answer_dict["Q1"] = Avg
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': None,
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %% [markdown]
# ## Q2. Calculate the top 5 brands(Make) with the most unique models, order your answer in descending order with respect to the number of unique models.
# ##### **NOTE:** Consider only the name of the models and their brand, that is use only the Make and Model columns
# ##### Format: A 5X2 list with each row being the name of the brand followed by the unique number of models, in descending order.
# #####Hint: You can use the pandas [df.values.tolist()](https://pandas.pydata.org/docs/reference/api/pandas.Series.tolist.html) function to format your answer.
#
# ##### Example answer:
# `[["Volkswagen", 1000], ["Toyota", 900], ["Honda", 800], ["Subaru", 700], ["Ford", 600]]`

# %%
q2 = data[['Make','Model']]
q2
# Out:
#                    Make                Model
# 0            AM General    DJ Po Vehicle 2WD
# 1            AM General     FJ8c Post Office
# 2            AM General  Post Office DJ5 2WD
# 3            AM General  Post Office DJ8 2WD
# 4      ASC Incorporated                  GNX
# ...                 ...                  ...
# 35947             smart         fortwo coupe
# 35948             smart         fortwo coupe
# 35949             smart         fortwo coupe
# 35950             smart         fortwo coupe
# 35951             smart         fortwo coupe
#
# [35952 rows x 2 columns]

# %%
# Number of diferent brands:
brands_number = q2['Make'].nunique()
brands_number
# Out:
# 127

# %%
brands_df = data['Make']
brands_df.drop_duplicates()
# Out:
# 0                         AM General
# 4                   ASC Incorporated
# 5                              Acura
# 307                       Alfa Romeo
# 348      American Motors Corporation
#                     ...
# 34128                     Volkswagen
# 35175                          Volvo
# 35892          Wallace Environmental
# 35924                           Yugo
# 35932                          smart
# Name: Make, Length: 127, dtype: object

# %%
for i in brands_number
    di = nunique()
# Out:
#   File "C:\Users\adria\AppData\Local\Temp/ipykernel_1264/1375928915.py", line 1
#     for i in brands_number
#                           ^
# SyntaxError: invalid syntax

# %%
unique_models_dict = {}
for i in brands_df: 
    
    # Clean duplicates in models of the same brand:
    x = q2[q2['Make'] == str(i)]['Model'].drop_duplicates()
    # Count the number of the models of the same brand:
    unique_values = q2[q2['Make'] == str(i)]['Model'].nunique()
    # Assign the unique values to the list 
    unique_models_dict[i] = unique_values

# %%
unique_models_lst = pd.DataFrame(unique_models_dict.items()).values.tolist()
unique_models_lst = sorted(unique_models_lst,key=lambda l:l[1], reverse=True)
answer_dict['Q2'] = unique_models_lst[:5]

# %%
answer_dict['Q2'] = unique_models_lst[:5]
answer_dict['Q2']
# Out:
# [['Mercedes-Benz', 333],
#  ['BMW', 284],
#  ['Chevrolet', 253],
#  ['Ford', 185],
#  ['GMC', 163]]

# %% [markdown]
# ## Q3. What are all the different types of fuels in the dataset sorted alphabetically?
# ##### Format: A list of strings sorted alphabetically.
# ##### Example Answer:
# `['Regular',
#  'Premium']`

# %%
########## Q3
Fuels = data['Fuel Type'].drop_duplicates()
Fuels_sorted = Fuels.sort_values(ascending=False).tolist()
#Example answer:
#answer_dict["Q3"] =  ['Regular', 'Premium'] 
answer_dict["Q3"] = Fuels_sorted
answer_dict["Q3"]
# Out:
# ['Regular Gas or Electricity',
#  'Regular Gas and Electricity',
#  'Regular',
#  'Premium or E85',
#  'Premium and Electricity',
#  'Premium Gas or Electricity',
#  'Premium',
#  'Midgrade',
#  'Gasoline or propane',
#  'Gasoline or natural gas',
#  'Gasoline or E85',
#  'Diesel',
#  'CNG']

# %% [markdown]
# ## Q.4 Show the 9 Toyota cars with the most extreme Fuel Barrels/Year in abosolute terms within all Toyota cars.
# #### Show the car Model, Year and their Fuel Barrels/Year in standard deviation units(Z-score) sorted in descending order by their Fuel Barrels/Year in absolute terms first and then by year in descending order BUT without modifying the negative values (see example).
# #### Format: A 9X3 list with each row containing the Model, Year and Fuel Barrels/Year in standard deviations units
# Example answer:
# [['DJ Po Vehicle 2WD', 2004, -6.407431084026927],
# ['FJ8c Post Office', 2003, -6.407431084026927],
# ['Post Office DJ5 2WD', 2005, -6.391684618442447],
# ['Sierra 2500 Hd 2WD', 2002, -6.391684618442447],
# ['Camry CNG', 2012, 2.677633075759575],
# ['Sierra 1500 4WD', 2005, 2.677633075759575],
# ['Sierra 1500 4WD', 2001, 2.677633075759575],
# ['V15 Suburban 4WD', 1988, 2.677633075759575],
# ['V15 Suburban 4WD', 1987, 2.677633075759575]]
#
# Note that while the list is sorted by the Fuel Barrels/Year in absolute terms and in standard deviation units, the values are not modified.
# If the values are the same the rows are sorted by the year.

# %%
########## Q4
# Filtering by brand
Toyota_Cars = data['Toyota' == data['Make']] 
# Dropping unnecessary columns
Toyota_Cars = Toyota_Cars[['Model','Year','Fuel Barrels/Year']]

# %% [markdown]
# ## Q.5 Calculate the changes in Combined MPG with their previous model of all Golf cars with Manual 5-spd transmission and Regular Fuel Type.
# #### Show the Year, the Combined MPG and the calculated difference of MPG in a list sorted by Year in ascending order.
# Format: A 19X3 list, with the Year and Combined MPG being of type integer and only the calculated difference is of type float
# Note: The value for the first model should be 0. It does not matter that there are gaps in the years, calculate with respect the previous model.
# #### Example answer:
# ```
# [[1986, 25, 0.0],
#  [1987, 25, 0.0],
#  [1988, 25, 0.0],
#  [1989, 25, 0.0],
#  [1990, 23, -2.0],
#  [1991, 23, 0.0],
#  [1992, 24, 1.0],
#  [1993, 25, 1.0],
#  [1994, 25, 0.0],
#  [1995, 25, 0.0],
#  [1996, 25, 0.0],
#  [1997, 25, 0.0],
#  [1998, 24, -1.0],
#  [1999, 25, 1.0],
#  [2000, 24, -1.0],
#  [2001, 24, 0.0],
#  [2002, 24, 0.0],
#  [2004, 24, 0.0],
#  [2006, 24, 0.0]]
#  ```

# %%
########## Q5
# Filtering data by models that include name 'Golf':
Golfs_df = data[True == data['Model'].str.contains('Golf')] 
Golfs_df
# Out:
#              Make        Model  Year  Engine Displacement  Cylinders  \
# 34365  Volkswagen  GTI/Golf GT  1987                  1.8        4.0
# 34366  Volkswagen  GTI/Golf GT  1987                  1.8        4.0
# 34367  Volkswagen         Golf  1986                  1.6        4.0
# 34368  Volkswagen         Golf  1986                  1.8        4.0
# 34369  Volkswagen         Golf  1986                  1.8        4.0
# ...           ...          ...   ...                  ...        ...
# 34478  Volkswagen     Golf/GTI  1998                  2.0        4.0
# 34822  Volkswagen     New Golf  1999                  1.9        4.0
# 34823  Volkswagen     New Golf  1999                  1.9        4.0
# 34824  Volkswagen     New Golf  1999                  2.0        4.0
# 34825  Volkswagen     New Golf  1999                  2.0        4.0
#
#           Transmission         Drivetrain Vehicle Class Fuel Type  \
# 34365  Automatic 3-spd  Front-Wheel Drive  Compact Cars   Regular
# ...

# %%
# Filtering by Transmission and Fuel Type conditions:
Golfs_df = Golfs_df[('Manual 5-spd'==Golfs_df['Transmission']) & ('Regular'==Golfs_df['Fuel Type'])]
Golfs_df
# Out:
#              Make            Model  Year  Engine Displacement  Cylinders  \
# 34366  Volkswagen      GTI/Golf GT  1987                  1.8        4.0
# 34369  Volkswagen             Golf  1986                  1.8        4.0
# 34372  Volkswagen             Golf  1987                  1.8        4.0
# 34374  Volkswagen             Golf  1988                  1.8        4.0
# 34377  Volkswagen             Golf  1989                  1.8        4.0
# 34379  Volkswagen             Golf  1999                  2.0        4.0
# 34385  Volkswagen             Golf  2000                  2.0        4.0
# 34391  Volkswagen             Golf  2001                  2.0        4.0
# 34395  Volkswagen             Golf  2002                  2.0        4.0
# 34399  Volkswagen             Golf  2003                  2.0        4.0
# 34403  Volkswagen             Golf  2004                  2.0        4.0
# 34407  Volkswagen             Golf  2005                  2.0        4.0
# ...

# %%
# Dropping unnecessary columns:
Golfs_df = Golfs_df[['Year','Combined MPG']]
Golfs_df
# Out:
#        Year  Combined MPG
# 34366  1987            25
# 34369  1986            26
# 34372  1987            26
# 34374  1988            25
# 34377  1989            25
# 34379  1999            24
# 34385  2000            24
# 34391  2001            24
# 34395  2002            24
# 34399  2003            24
# 34403  2004            24
# 34407  2005            24
# 34411  2006            24
# 34412  2010            25
# 34417  2011            26
# 34421  2012            26
# 34427  2013            26
# 34431  2015            30
# 34436  2016            30
# 34438  2017            29
# 34440  1994            24
# 34442  1995            24
# 34444  1993            24
# 34456  2015            29
# 34458  2016            29
# 34460  2017            28
# 34463  1985            25
# 34464  1985            26
# 34466  1990            25
# 34468  1991            25
# 34470  1992            25
# 34473  1996            23
# 34476  1997            24
# 34478  1998            24
# ...

# %%
# Adding column:
prev = np.array([[0],[Golfs_df['Combined MPG']]])

#Golfs_df = Golfs_df['Combined_MPG']
# Out:
# C:\Users\adria\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   if sys.path[0] == '':

# %% [markdown]
# ## Q6. What are the top 5 lowest CO2 Emission Grams/Mile emmisions of cars for each of the following brands: Toyota, Ford, Volkswagen, Nissan, Honda

# %%
########## Q6
# Filtering by brand and CO2 Emission Grams/Mile:
Toyota_lco2e = data['Toyota' == data['Make']][['Make','CO2 Emission Grams/Mile']] 
# Sort and take TOP 5:
Toyota_lco2e.sort_values('CO2 Emission Grams/Mile',inplace=True)
Toyota_lco2e = Toyota_lco2e.iloc[:5]
Toyota_lco2e
# Out:
#          Make  CO2 Emission Grams/Mile
# 33284  Toyota                    133.0
# 33283  Toyota                    133.0
# 33282  Toyota                    133.0
# 33281  Toyota                    133.0
# 33280  Toyota                    158.0

# %%
Ford_lco2e = data['Ford' == data['Make']][['Make','CO2 Emission Grams/Mile']]
Ford_lco2e.sort_values('CO2 Emission Grams/Mile',inplace=True)
Ford_lco2e = Ford_lco2e.iloc[:5]
Ford_lco2e
# Out:
#        Make  CO2 Emission Grams/Mile
# 13412  Ford                    112.0
# 13411  Ford                    129.0
# 13410  Ford                    129.0
# 13409  Ford                    129.0
# 13408  Ford                    129.0

# %%
Volks_lco2e = data['Volkswagen' == data['Make']][['Make','CO2 Emission Grams/Mile']]
Volks_lco2e.sort_values('CO2 Emission Grams/Mile',inplace=True)
Volks_lco2e = Volks_lco2e.iloc[:5]
Volks_lco2e
# Out:
#              Make  CO2 Emission Grams/Mile
# 34667  Volkswagen               200.000000
# 34664  Volkswagen               200.000000
# 34665  Volkswagen               200.000000
# 34666  Volkswagen               200.000000
# 34720  Volkswagen               261.025641

# %%
Nissan_lco2e = data['Nissan' == data['Make']][['Make','CO2 Emission Grams/Mile']]
Nissan_lco2e.sort_values('CO2 Emission Grams/Mile',inplace=True)
Nissan_lco2e = Nissan_lco2e.iloc[:5]
Nissan_lco2e
# Out:
#          Make  CO2 Emission Grams/Mile
# 27201  Nissan                    249.0
# 27198  Nissan                    254.0
# 26830  Nissan                    254.5
# 26835  Nissan                    254.5
# 26832  Nissan                    254.5

# %%
Honda_lco2e = data['Honda' == data['Make']][['Make','CO2 Emission Grams/Mile']]
Honda_lco2e.sort_values('CO2 Emission Grams/Mile',inplace=True)
Honda_lco2e = Honda_lco2e.iloc[:5]
Honda_lco2e
# Out:
#         Make  CO2 Emission Grams/Mile
# 17059  Honda               130.000000
# 17528  Honda               167.679245
# 17526  Honda               167.679245
# 17524  Honda               167.679245
# 17522  Honda               167.679245

# %%
lst = []
lst.append(['Toyota',Toyota_lco2e['CO2 Emission Grams/Mile'].to_list()])
lst.append(['Ford',Toyota_lco2e['CO2 Emission Grams/Mile'].to_list()])
lst.append(['Volkswagen',Toyota_lco2e['CO2 Emission Grams/Mile'].to_list()])
lst.append(['Nissan',Nissan_lco2e['CO2 Emission Grams/Mile'].to_list()])
lst.append(['Honda',Honda_lco2e['CO2 Emission Grams/Mile'].to_list()])

answer_dict['Q6'] = lst
answer_dict
# Out:
# {'Q1': None,
#  'Q2': None,
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6': [['Toyota', [133.0, 133.0, 133.0, 133.0, 158.0]],
#   ['Ford', [133.0, 133.0, 133.0, 133.0, 158.0]],
#   ['Volkswagen', [133.0, 133.0, 133.0, 133.0, 158.0]],
#   ['Nissan', [249.0, 254.0, 254.5, 254.5, 254.5]],
#   ['Honda',
#    [130.0,
#     167.67924528301887,
#     167.67924528301887,
#     167.67924528301887,
#     167.67924528301887]]],
#  'Q7': None}

# %% [markdown]
# ## Q.7

# %% [markdown]
# ## Saving results to Answers dictionary:

# %%
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Mercedes-Benz', 333],
#   ['BMW', 284],
#   ['Chevrolet', 253],
#   ['Ford', 185],
#   ['GMC', 163]],
#  'Q3': ['Regular Gas or Electricity',
#   'Regular Gas and Electricity',
#   'Regular',
#   'Premium or E85',
#   'Premium and Electricity',
#   'Premium Gas or Electricity',
#   'Premium',
#   'Midgrade',
#   'Gasoline or propane',
#   'Gasoline or natural gas',
#   'Gasoline or E85',
#   'Diesel',
#   'CNG'],
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %%
import pickle

file_name = "Adrian_Ramos_answers.pkl"
path = "../"

with open(path+file_name, 'wb') as f:
    pickle.dump(answer_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

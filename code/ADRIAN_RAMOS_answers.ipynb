# %% [markdown]
# <a id='top'></a>
#
# <div>
#   <img src="../images/main_logo_black_X2.png" style="width:10px;height:10px; vertical-align:middle;" align="middle">
# </div>
# <h1><center>WIZELINE ACADEMY: DATA ENGINEERING BOOTCAMP 2022</center></h1>

# %% [markdown]
# <form action="/action_page.php">
#   <fieldset>
#     <legend><strong>Code Challenge presented by</strong></legend>
#
#    <div class="card">
#   <h4 class="card-header"> Adrian Ramos Perez &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;June 5th 2022 </h4>
#   <div class="card-body">
#       <h5 class="card-title">📬<a href="mailto:adrian.ramos@iteso.mx"> adrian.ramos@iteso.mx</a></h5>
#
#   </div>
# </div>
#
#   </fieldset>
# </form>

# %% [markdown]
# # Data Bootcamp Selection Challenge
# ##### In this challenge you will calculate various KPIs using a car based dataset, each question will have a single correct answer that will be evaluated through automated unit testing. Use the dictionary provided below to fill in your answers, each question will state the format required for the answer and examples are provided so you know how properly fill the answer dictionary.
# ##### **Use the dataset "as is" and do not perform any data cleaning or modify it in any way, doing so could make you answer all your questions incorrectly. Do not modify the structure of the answer dictionary.**
#
# ##### When you finish this challenge please upload both your notebook and your answer dictionary in pickle format to a public github repository submit their URL to the [google form](https://forms.gle/wWysZEMkoZsjB11Y7) that was provided to you.
#
# ##### Some unit tests are provided at the end of this notebook to help you verify your answers are in the correct format, however they will not test everything.

# %% [markdown]
# <a id='contents_table'></a>
#
# # Table of Contents <a id='contents'></a>
# -----
# * [Top](#top)
# * [Q1. Average CO2 emmission per gram/mile of all Volkswagen cars ](#q1)
# * [Q2. Top 5 brands(Make) with the most unique models](#q2)
# * [Q3. Different types of fuels in the dataset](#q3)
# * [Q4. Top 9 Toyota cars with the most extreme Fuel Barrels/Year in abosolute terms](#q4)
# * [Q5. Changes in Combined MPG with their previous model of all Golf cars with Manual 5-spd transmission and Regular Fuel Type](#q5)
# * [Q6. Top 5 lowest CO2 Emission Grams/Mile emmisions of cars of brands: Toyota, Ford, Volkswagen, Nissan, Honda](#q6)
# * [Q7. groups of 5 years to calculat the median of Combined MPG of each group](#q7)
# * [Annex 1. Saving results to pickle](#saving_to_pickle)
# * [Annex 2. Unit Tests](#unit_tests)

# %%
# Dictionary to store answers:
answer_dict =  {"Q1" : None,
                "Q2" : None,
                "Q3" : None,
                "Q4" : None,
                "Q5" : None,
                "Q6" : None,
                "Q7" : None}
answer_dict
# Out:
# {'Q1': None,
#  'Q2': None,
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %%
import pandas as pd
import numpy as np
url='https://drive.google.com/file/d/1PCJ7ltluquoXKi6MYTPMfwZQNI_-MIFP/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
data = pd.read_csv(url)

data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
#  14  Fuel Cost/Year           35952 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 4.1+ MB

# %% [markdown]
# ---

# %% [markdown]
# <a id='q1'></a>
# [Table of Contents](#contents_table)
#
# # Q1. What is the average CO2 emmission per gram/mile of all Volkswagen cars?
# #### Format: A floating number
# #### Example answer: 11.547
# ---

# %%
########## Q1
Volkswagen_cars = data[data['Make']=='Volkswagen']
Avg = Volkswagen_cars['CO2 Emission Grams/Mile'].mean()
Avg
# Out:
# 392.7417210857633

# %%
answer_dict["Q1"] = Avg
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': None,
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %% [markdown]
# ---

# %% [markdown]
# <a id='q2'></a>
# [Table of Contents](#contents_table)
#
# # Q2. Calculate the top 5 brands(Make) with the most unique models, order your answer in descending order with respect to the number of unique models.
# ##### **NOTE:** Consider only the name of the models and their brand, that is use only the Make and Model columns
# ##### Format: A 5X2 list with each row being the name of the brand followed by the unique number of models, in descending order.
# ##### Hint: You can use the pandas [df.values.tolist()](https://pandas.pydata.org/docs/reference/api/pandas.Series.tolist.html) function to format your answer.
#
# ##### Example answer:
# `[["Volkswagen", 1000], ["Toyota", 900], ["Honda", 800], ["Subaru", 700], ["Ford", 600]]`
#
# ---

# %%
q2 = data[['Make','Model']]
q2
# Out:
#                    Make                Model
# 0            AM General    DJ Po Vehicle 2WD
# 1            AM General     FJ8c Post Office
# 2            AM General  Post Office DJ5 2WD
# 3            AM General  Post Office DJ8 2WD
# 4      ASC Incorporated                  GNX
# ...                 ...                  ...
# 35947             smart         fortwo coupe
# 35948             smart         fortwo coupe
# 35949             smart         fortwo coupe
# 35950             smart         fortwo coupe
# 35951             smart         fortwo coupe
#
# [35952 rows x 2 columns]

# %%
# Counting different brands:
brands_number = q2['Make'].nunique()
brands_number
# Out:
# 127

# %%
# Saving into a brand dataset of all unrepeated brands:
brands_df = data['Make']
brands_df.drop_duplicates(inplace=True)
brands_df
# Out:
# 0                         AM General
# 4                   ASC Incorporated
# 5                              Acura
# 307                       Alfa Romeo
# 348      American Motors Corporation
#                     ...
# 34128                     Volkswagen
# 35175                          Volvo
# 35892          Wallace Environmental
# 35924                           Yugo
# 35932                          smart
# Name: Make, Length: 127, dtype: object

# %%
unique_models_dict = {}
# Iterating through the brands dataset:
for i in brands_df: 
    
    # Clean duplicates in models of the same brand:
    x = q2[q2['Make'] == str(i)]['Model'].drop_duplicates()
    # Count the number of unique models of the same brand:
    unique_values = q2[q2['Make'] == str(i)]['Model'].nunique()
    # Assign the unique values to the list 
    unique_models_dict[i] = unique_values

# %%
unique_models_lst = pd.DataFrame(unique_models_dict.items()).values.tolist()
unique_models_lst
# Out:
# [['AM General', 4],
#  ['ASC Incorporated', 1],
#  ['Acura', 39],
#  ['Alfa Romeo', 8],
#  ['American Motors Corporation', 4],
#  ['Aston Martin', 30],
#  ['Audi', 95],
#  ['Aurora Cars Ltd', 1],
#  ['Autokraft Limited', 2],
#  ['BMW', 284],
#  ['BMW Alpina', 2],
#  ['Bentley', 22],
#  ['Bertone', 1],
#  ['Bill Dovell Motor Car Company', 2],
#  ['Bitter Gmbh and Co. Kg', 1],
#  ['Bugatti', 1],
#  ['Buick', 44],
#  ['CCC Engineering', 1],
#  ['CX Automotive', 7],
#  ['Cadillac', 66],
#  ['Chevrolet', 253],
#  ['Chrysler', 65],
#  ['Consulier Industries Inc', 1],
#  ['Dabryan Coach Builders Inc', 1],
#  ['Dacia', 3],
#  ['Daewoo', 8],
#  ['Daihatsu', 3],
#  ['Dodge', 118],
#  ['E. P. Dutton, Inc.', 1],
#  ['Eagle', 10],
#  ['Environmental Rsch and Devp Corp', 1],
#  ['Evans Automobiles', 2],
#  ['Excalibur Autos', 1],
#  ['Federal Coach', 14],
#  ['Ferrari', 60],
#  ['Fiat', 7],
#  ['Fisker', 1],
#  ['Ford', 185],
#  ['GMC', 163],
#  ['General Motors', 1],
#  ['Genesis', 4],
#  ['Geo', 15],
#  ['Goldacre', 1],
#  ['Grumman Allied Industries', 1],
#  ['Grumman Olson', 1],
#  ['Honda', 45],
#  ['Hummer', 4],
#  ['Hyundai', 64],
#  ['Import Foreign Auto Sales Inc', 1],
#  ['Import Trade Services', 12],
#  ['Infiniti', 82],
#  ['Isis Imports Ltd', 1],
#  ['Isuzu', 36],
#  ['J.K. Motors', 21],
#  ['JBA Motorcars, Inc.', 1],
#  ['Jaguar', 66],
#  ['Jeep', 50],
#  ['Kia', 42],
#  ['Laforza Automobile Inc', 1],
#  ['Lambda Control Systems', 1],
#  ['Lamborghini', 23],
#  ['Land Rover', 26],
#  ['Lexus', 72],
#  ['Lincoln', 37],
#  ['London Coach Co Inc', 1],
#  ['London Taxi', 1],
#  ['Lotus', 10],
#  ['MINI', 42],
#  ['Mahindra', 1],
#  ['Maserati', 31],
#  ['Maybach', 8],
#  ['Mazda', 74],
#  ['McLaren Automotive', 8],
#  ['Mcevoy Motors', 4],
#  ['Mercedes-Benz', 333],
#  ['Mercury', 51],
#  ['Merkur', 2],
#  ['Mitsubishi', 51],
#  ['Mobility Ventures LLC', 2],
#  ['Morgan', 1],
#  ['Nissan', 94],
#  ['Oldsmobile', 33],
#  ['PAS Inc - GMC', 2],
#  ['PAS, Inc', 2],
#  ['Pagani', 1],
#  ['Panos', 1],
#  ['Panoz Auto-Development', 1],
#  ['Panther Car Company Limited', 1],
#  ['Peugeot', 7],
#  ['Pininfarina', 1],
#  ['Plymouth', 23],
#  ['Pontiac', 57],
#  ['Porsche', 121],
#  ['Quantum Technologies', 1],
#  ['Qvale', 1],
#  ['Ram', 7],
#  ['Red Shift Ltd.', 1],
#  ['Renault', 8],
#  ['Rolls-Royce', 47],
#  ['Roush Performance', 18],
#  ['Ruf Automobile Gmbh', 1],
#  ['S and S Coach Company  E.p. Dutton', 1],
#  ['SRT', 1],
#  ['Saab', 28],
#  ['Saleen', 3],
#  ['Saleen Performance', 3],
#  ['Saturn', 24],
#  ['Scion', 8],
#  ['Shelby', 1],
#  ['Spyker', 7],
#  ['Sterling', 2],
#  ['Subaru', 61],
#  ['Superior Coaches Div E.p. Dutton', 1],
#  ['Suzuki', 77],
#  ['TVR Engineering Ltd', 4],
#  ['Tecstar, LP', 6],
#  ['Texas Coach Company', 4],
#  ['Toyota', 100],
#  ['VPG', 2],
#  ['Vector', 2],
#  ['Vixen Motor Company', 1],
#  ['Volga Associated Automobile', 1],
#  ['Volkswagen', 63],
#  ['Volvo', 83],
#  ['Wallace Environmental', 18],
#  ['Yugo', 4],
#  ['smart', 3]]

# %%
# Sorting by number of unique models per brand, in descending order:
unique_models_lst = sorted(unique_models_lst,key=lambda l:l[1], reverse=True)
unique_models_lst
# Out:
# [['Mercedes-Benz', 333],
#  ['BMW', 284],
#  ['Chevrolet', 253],
#  ['Ford', 185],
#  ['GMC', 163],
#  ['Porsche', 121],
#  ['Dodge', 118],
#  ['Toyota', 100],
#  ['Audi', 95],
#  ['Nissan', 94],
#  ['Volvo', 83],
#  ['Infiniti', 82],
#  ['Suzuki', 77],
#  ['Mazda', 74],
#  ['Lexus', 72],
#  ['Cadillac', 66],
#  ['Jaguar', 66],
#  ['Chrysler', 65],
#  ['Hyundai', 64],
#  ['Volkswagen', 63],
#  ['Subaru', 61],
#  ['Ferrari', 60],
#  ['Pontiac', 57],
#  ['Mercury', 51],
#  ['Mitsubishi', 51],
#  ['Jeep', 50],
#  ['Rolls-Royce', 47],
#  ['Honda', 45],
#  ['Buick', 44],
#  ['Kia', 42],
#  ['MINI', 42],
#  ['Acura', 39],
#  ['Lincoln', 37],
#  ['Isuzu', 36],
#  ['Oldsmobile', 33],
#  ['Maserati', 31],
#  ['Aston Martin', 30],
#  ['Saab', 28],
#  ['Land Rover', 26],
#  ['Saturn', 24],
#  ['Lamborghini', 23],
#  ['Plymouth', 23],
#  ['Bentley', 22],
#  ['J.K. Motors', 21],
#  ['Roush Performance', 18],
#  ['Wallace Environmental', 18],
#  ['Geo', 15],
#  ['Federal Coach', 14],
#  ['Import Trade Services', 12],
#  ['Eagle', 10],
#  ['Lotus', 10],
#  ['Alfa Romeo', 8],
#  ['Daewoo', 8],
#  ['Maybach', 8],
#  ['McLaren Automotive', 8],
#  ['Renault', 8],
#  ['Scion', 8],
#  ['CX Automotive', 7],
#  ['Fiat', 7],
#  ['Peugeot', 7],
#  ['Ram', 7],
#  ['Spyker', 7],
#  ['Tecstar, LP', 6],
#  ['AM General', 4],
#  ['American Motors Corporation', 4],
#  ['Genesis', 4],
#  ['Hummer', 4],
#  ['Mcevoy Motors', 4],
#  ['TVR Engineering Ltd', 4],
#  ['Texas Coach Company', 4],
#  ['Yugo', 4],
#  ['Dacia', 3],
#  ['Daihatsu', 3],
#  ['Saleen', 3],
#  ['Saleen Performance', 3],
#  ['smart', 3],
#  ['Autokraft Limited', 2],
#  ['BMW Alpina', 2],
#  ['Bill Dovell Motor Car Company', 2],
#  ['Evans Automobiles', 2],
#  ['Merkur', 2],
#  ['Mobility Ventures LLC', 2],
#  ['PAS Inc - GMC', 2],
#  ['PAS, Inc', 2],
#  ['Sterling', 2],
#  ['VPG', 2],
#  ['Vector', 2],
#  ['ASC Incorporated', 1],
#  ['Aurora Cars Ltd', 1],
#  ['Bertone', 1],
#  ['Bitter Gmbh and Co. Kg', 1],
#  ['Bugatti', 1],
#  ['CCC Engineering', 1],
#  ['Consulier Industries Inc', 1],
#  ['Dabryan Coach Builders Inc', 1],
#  ['E. P. Dutton, Inc.', 1],
#  ['Environmental Rsch and Devp Corp', 1],
#  ['Excalibur Autos', 1],
#  ['Fisker', 1],
#  ['General Motors', 1],
#  ['Goldacre', 1],
#  ['Grumman Allied Industries', 1],
#  ['Grumman Olson', 1],
#  ['Import Foreign Auto Sales Inc', 1],
#  ['Isis Imports Ltd', 1],
#  ['JBA Motorcars, Inc.', 1],
#  ['Laforza Automobile Inc', 1],
#  ['Lambda Control Systems', 1],
#  ['London Coach Co Inc', 1],
#  ['London Taxi', 1],
#  ['Mahindra', 1],
#  ['Morgan', 1],
#  ['Pagani', 1],
#  ['Panos', 1],
#  ['Panoz Auto-Development', 1],
#  ['Panther Car Company Limited', 1],
#  ['Pininfarina', 1],
#  ['Quantum Technologies', 1],
#  ['Qvale', 1],
#  ['Red Shift Ltd.', 1],
#  ['Ruf Automobile Gmbh', 1],
#  ['S and S Coach Company  E.p. Dutton', 1],
#  ['SRT', 1],
#  ['Shelby', 1],
#  ['Superior Coaches Div E.p. Dutton', 1],
#  ['Vixen Motor Company', 1],
#  ['Volga Associated Automobile', 1]]

# %%
answer_dict['Q2'] = unique_models_lst[:5]
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Mercedes-Benz', 333],
#   ['BMW', 284],
#   ['Chevrolet', 253],
#   ['Ford', 185],
#   ['GMC', 163]],
#  'Q3': None,
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %% [markdown]
# ---

# %% [markdown]
# <a id='q3'></a>
# [Table of Contents](#contents_table)
#
# # Q3. What are all the different types of fuels in the dataset sorted alphabetically?
# ##### Format: A list of strings sorted alphabetically.
# ##### Example Answer:
# `['Regular', 'Premium']`
#
# ---

# %%
########## Q3
Fuels = data['Fuel Type'].drop_duplicates()
Fuels_sorted = Fuels.sort_values(ascending=False).tolist()
#Example answer:
#answer_dict["Q3"] =  ['Regular', 'Premium'] 
answer_dict["Q3"] = Fuels_sorted
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Mercedes-Benz', 333],
#   ['BMW', 284],
#   ['Chevrolet', 253],
#   ['Ford', 185],
#   ['GMC', 163]],
#  'Q3': ['Regular Gas or Electricity',
#   'Regular Gas and Electricity',
#   'Regular',
#   'Premium or E85',
#   'Premium and Electricity',
#   'Premium Gas or Electricity',
#   'Premium',
#   'Midgrade',
#   'Gasoline or propane',
#   'Gasoline or natural gas',
#   'Gasoline or E85',
#   'Diesel',
#   'CNG'],
#  'Q4': None,
#  'Q5': None,
#  'Q6': None,
#  'Q7': None}

# %% [markdown]
# ---

# %% [markdown]
# <a id='q4'></a>
# [Table of Contents](#contents_table)
#
# # Q.4 Show the 9 Toyota cars with the most extreme Fuel Barrels/Year in abosolute terms within all Toyota cars.
# * Show the car Model, Year and their Fuel Barrels/Year **in standard deviation units(Z-score)**,
# - sorted in descending order by their Fuel Barrels/Year in absolute terms first and then by year in descending order BUT without modifying the negative values (see example).
# * Format: A 9X3 list with each row containing the Model, Year and Fuel Barrels/Year **in standard deviations units**
#
# Example answer:
# ```
# [['DJ Po Vehicle 2WD', 2004, -6.407431084026927],
# ['FJ8c Post Office', 2003, -6.407431084026927],
# ['Post Office DJ5 2WD', 2005, -6.391684618442447],
# ['Sierra 2500 Hd 2WD', 2002, -6.391684618442447],
# ['Camry CNG', 2012, 2.677633075759575],
# ['Sierra 1500 4WD', 2005, 2.677633075759575],
# ['Sierra 1500 4WD', 2001, 2.677633075759575],
# ['V15 Suburban 4WD', 1988, 2.677633075759575],
# ['V15 Suburban 4WD', 1987, 2.677633075759575]]
# ```
#
# **Note that while the list is sorted by the Fuel Barrels/Year in absolute terms and in standard deviation units, the values are not modified.
# If the values are the same the rows are sorted by the year.**
#
# ---

# %%
########## Q4
# Filtering by brand
Toyota_Cars = data['Toyota' == data['Make']] 
# Dropping unnecessary columns
Toyota_Cars = Toyota_Cars[['Model','Year','Fuel Barrels/Year']]
Toyota_Cars
# Out:
#                  Model  Year  Fuel Barrels/Year
# 32281  1-Ton Truck 2WD  1985          15.695714
# 32282  1-Ton Truck 2WD  1985          15.695714
# 32283  1-Ton Truck 2WD  1986          15.695714
# 32284  1-Ton Truck 2WD  1986          14.330870
# 32285  1-Ton Truck 2WD  1987          15.695714
# ...                ...   ...                ...
# 34112            Yaris  2016           9.988182
# 34113            Yaris  2017          10.300313
# 34114            Yaris  2017           9.988182
# 34115         Yaris iA  2017           9.694412
# 34116         Yaris iA  2017           9.417429
#
# [1836 rows x 3 columns]

# %% [markdown]
# ### Z-Score value:

# %%
Toyota_Cars['Mean'] = Toyota_Cars['Fuel Barrels/Year'].mean()
Toyota_Cars['Std Dev'] = Toyota_Cars['Fuel Barrels/Year'].std()
Toyota_Cars['Z-score']  = (Toyota_Cars['Fuel Barrels/Year'] - Toyota_Cars['Mean'])/Toyota_Cars['Std Dev'] 
Toyota_Cars
# Out:
#                  Model  Year  Fuel Barrels/Year       Mean  Std Dev   Z-score
# 32281  1-Ton Truck 2WD  1985          15.695714  16.153677  4.08713 -0.112050
# 32282  1-Ton Truck 2WD  1985          15.695714  16.153677  4.08713 -0.112050
# 32283  1-Ton Truck 2WD  1986          15.695714  16.153677  4.08713 -0.112050
# 32284  1-Ton Truck 2WD  1986          14.330870  16.153677  4.08713 -0.445987
# 32285  1-Ton Truck 2WD  1987          15.695714  16.153677  4.08713 -0.112050
# ...                ...   ...                ...        ...      ...       ...
# 34112            Yaris  2016           9.988182  16.153677  4.08713 -1.508515
# 34113            Yaris  2017          10.300313  16.153677  4.08713 -1.432146
# 34114            Yaris  2017           9.988182  16.153677  4.08713 -1.508515
# 34115         Yaris iA  2017           9.694412  16.153677  4.08713 -1.580392
# 34116         Yaris iA  2017           9.417429  16.153677  4.08713 -1.648161
#
# [1836 rows x 6 columns]

# %%
# Sorting by absolute value of Z-Score:
Toyota_Cars['Z-score abs'] = np.abs(Toyota_Cars['Z-score'])
Toyota_Cars = Toyota_Cars.sort_values('Z-score abs', ascending=False)
Toyota_Cars
# Out:
#                  Model  Year  Fuel Barrels/Year       Mean  Std Dev   Z-score  \
# 32473  Cab/Chassis 2WD  1989            32.9610  16.153677  4.08713  4.112256
# 32481  Cab/Chassis 2WD  1993            32.9610  16.153677  4.08713  4.112256
# 32475  Cab/Chassis 2WD  1990            32.9610  16.153677  4.08713  4.112256
# 32477  Cab/Chassis 2WD  1991            32.9610  16.153677  4.08713  4.112256
# 32479  Cab/Chassis 2WD  1992            32.9610  16.153677  4.08713  4.112256
# ...                ...   ...                ...        ...      ...       ...
# 32306      4Runner 2WD  1996            16.4805  16.153677  4.08713  0.079964
# 33866        Truck 2WD  1991            16.4805  16.153677  4.08713  0.079964
# 32505            Camry  1990            16.4805  16.153677  4.08713  0.079964
# 32739           Celica  1993            16.4805  16.153677  4.08713  0.079964
# 33083   Highlander AWD  2014            16.4805  16.153677  4.08713  0.079964
#
#        Z-score abs
# 32473     4.112256
# 32481     4.112256
# 32475     4.112256
# 32477     4.112256
# 32479     4.112256
# ...            ...
# 32306     0.079964
# 33866     0.079964
# 32505     0.079964
# 32739     0.079964
# 33083     0.079964
#
# [1836 rows x 7 columns]

# %%
# Sorting TOP 9 by year in descending order:
Toyota_Cars = Toyota_Cars[:9].sort_values('Year', ascending=False)
Toyota_Cars
# Out:
#                  Model  Year  Fuel Barrels/Year       Mean  Std Dev   Z-score  \
# 32602        Camry CNG  2001           0.084545  16.153677  4.08713 -3.931642
# 32601        Camry CNG  2000           0.084545  16.153677  4.08713 -3.931642
# 32600        Camry CNG  1999           0.080870  16.153677  4.08713 -3.932542
# 32481  Cab/Chassis 2WD  1993          32.961000  16.153677  4.08713  4.112256
# 32479  Cab/Chassis 2WD  1992          32.961000  16.153677  4.08713  4.112256
# 32480  Cab/Chassis 2WD  1992          29.964545  16.153677  4.08713  3.379112
# 32477  Cab/Chassis 2WD  1991          32.961000  16.153677  4.08713  4.112256
# 32475  Cab/Chassis 2WD  1990          32.961000  16.153677  4.08713  4.112256
# 32473  Cab/Chassis 2WD  1989          32.961000  16.153677  4.08713  4.112256
#
#        Z-score abs
# 32602     3.931642
# 32601     3.931642
# 32600     3.932542
# 32481     4.112256
# 32479     4.112256
# 32480     3.379112
# 32477     4.112256
# 32475     4.112256
# 32473     4.112256

# %%
answer_dict['Q4'] = Toyota_Cars[['Model','Year','Z-score']].values.tolist()
answer_dict['Q4']
# Out:
# [['Camry CNG', 2001, -3.9316423754756538],
#  ['Camry CNG', 2000, -3.9316423754756538],
#  ['Camry CNG', 1999, -3.932541757118491],
#  ['Cab/Chassis 2WD', 1993, 4.1122558654247925],
#  ['Cab/Chassis 2WD', 1992, 4.1122558654247925],
#  ['Cab/Chassis 2WD', 1992, 3.3791118637260937],
#  ['Cab/Chassis 2WD', 1991, 4.1122558654247925],
#  ['Cab/Chassis 2WD', 1990, 4.1122558654247925],
#  ['Cab/Chassis 2WD', 1989, 4.1122558654247925]]

# %% [markdown]
# ---

# %% [markdown]
# <a id='q5'></a>
# [Table of Contents](#contents_table)
#
# # Q.5 Calculate the changes in Combined MPG with their previous model of all Golf cars with Manual 5-spd transmission and Regular Fuel Type.
# * Show the Year, the Combined MPG and the calculated difference of MPG in a list sorted by Year in ascending order.
# * Format: A 19X3 list, with the Year and Combined MPG being of type integer and only the calculated difference is of type float
# #### Note: The value for the first model should be 0. It does not matter that there are gaps in the years, calculate with respect the previous model.
#
# Example answer:
# ```
# [[1986, 25, 0.0],
#  [1987, 25, 0.0],
#  [1988, 25, 0.0],
#  [1989, 25, 0.0],
#  [1990, 23, -2.0],
#  [1991, 23, 0.0],
#  [1992, 24, 1.0],
#  [1993, 25, 1.0],
#  [1994, 25, 0.0],
#  [1995, 25, 0.0],
#  [1996, 25, 0.0],
#  [1997, 25, 0.0],
#  [1998, 24, -1.0],
#  [1999, 25, 1.0],
#  [2000, 24, -1.0],
#  [2001, 24, 0.0],
#  [2002, 24, 0.0],
#  [2004, 24, 0.0],
#  [2006, 24, 0.0]]
#  ```
#
#  ---

# %%
########## Q5
# Filtering data by models that include name 'Golf':
# Golfs_df = data[True == data['Model'].str.contains('Golf')] 
Golfs_df = data['Golf' == data['Model']]
Golfs_df
# Out:
#              Make Model  Year  Engine Displacement  Cylinders  \
# 34367  Volkswagen  Golf  1986                  1.6        4.0
# 34368  Volkswagen  Golf  1986                  1.8        4.0
# 34369  Volkswagen  Golf  1986                  1.8        4.0
# 34370  Volkswagen  Golf  1987                  1.6        4.0
# 34371  Volkswagen  Golf  1987                  1.8        4.0
# ...           ...   ...   ...                  ...        ...
# 34434  Volkswagen  Golf  2015                  2.0        4.0
# 34435  Volkswagen  Golf  2016                  1.8        4.0
# 34436  Volkswagen  Golf  2016                  1.8        4.0
# 34437  Volkswagen  Golf  2017                  1.8        4.0
# 34438  Volkswagen  Golf  2017                  1.8        4.0
#
#           Transmission         Drivetrain Vehicle Class Fuel Type  \
# 34367     Manual 5-spd  Front-Wheel Drive  Compact Cars    Diesel
# 34368  Automatic 3-spd  Front-Wheel Drive  Compact Cars   Regular
# 34369     Manual 5-spd  Front-Wheel Drive  Compact Cars   Regular
# 34370     Manual 5-spd  Front-Wheel Drive  Compact Cars    Diesel
# 34371  Automatic 3-spd  Front-Wheel Drive  Compact Cars   Regular
# ...                ...                ...           ...       ...
# 34434     Manual 6-spd  Front-Wheel Drive  Compact Cars    Diesel
# 34435   Automatic (S6)  Front-Wheel Drive  Compact Cars   Regular
# 34436     Manual 5-spd  Front-Wheel Drive  Compact Cars   Regular
# 34437   Automatic (S6)  Front-Wheel Drive  Compact Cars   Regular
# 34438     Manual 5-spd  Front-Wheel Drive  Compact Cars   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 34367          10.919571        31           40            35
# 34368          14.982273        21           25            22
# 34369          12.677308        23           31            26
# 34370          11.581364        31           37            33
# 34371          14.982273        21           25            22
# ...                  ...       ...          ...           ...
# 34434          10.616250        30           45            36
# 34435          11.365862        25           36            29
# 34436          10.987000        25           37            30
# 34437          11.365862        25           35            29
# 34438          11.365862        25           36            29
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 34367               290.857143            1050
# 34368               403.954545            1500
# 34369               341.807692            1300
# 34370               308.484848            1100
# 34371               403.954545            1500
# ...                        ...             ...
# 34434               286.000000            1000
# 34435               305.000000            1150
# 34436               300.000000            1100
# 34437               309.000000            1150
# 34438               305.000000            1150
#
# [72 rows x 15 columns]

# %%
# Filtering by Transmission and Fuel Type conditions & Dropping unnecessary columns::
Golfs_df = Golfs_df[('Manual 5-spd'==Golfs_df['Transmission']) & ('Regular'==Golfs_df['Fuel Type'])][['Year','Combined MPG']]
Golfs_df
# Out:
#        Year  Combined MPG
# 34369  1986            26
# 34372  1987            26
# 34374  1988            25
# 34377  1989            25
# 34379  1999            24
# 34385  2000            24
# 34391  2001            24
# 34395  2002            24
# 34399  2003            24
# 34403  2004            24
# 34407  2005            24
# 34411  2006            24
# 34412  2010            25
# 34417  2011            26
# 34421  2012            26
# 34427  2013            26
# 34431  2015            30
# 34436  2016            30
# 34438  2017            29

# %%
# Adding column:
Golfs_df['Difference'] = Golfs_df['Combined MPG'] - Golfs_df['Combined MPG'].shift(periods=1)
Golfs_df.fillna(0,inplace=True)
lst_q5 = Golfs_df.values.tolist()
lst_q5
# Out:
# [[1986.0, 26.0, 0.0],
#  [1987.0, 26.0, 0.0],
#  [1988.0, 25.0, -1.0],
#  [1989.0, 25.0, 0.0],
#  [1999.0, 24.0, -1.0],
#  [2000.0, 24.0, 0.0],
#  [2001.0, 24.0, 0.0],
#  [2002.0, 24.0, 0.0],
#  [2003.0, 24.0, 0.0],
#  [2004.0, 24.0, 0.0],
#  [2005.0, 24.0, 0.0],
#  [2006.0, 24.0, 0.0],
#  [2010.0, 25.0, 1.0],
#  [2011.0, 26.0, 1.0],
#  [2012.0, 26.0, 0.0],
#  [2013.0, 26.0, 0.0],
#  [2015.0, 30.0, 4.0],
#  [2016.0, 30.0, 0.0],
#  [2017.0, 29.0, -1.0]]

# %%
answer_dict['Q5'] = lst_q5
answer_dict['Q5']
# Out:
# [[1986.0, 26.0, 0.0],
#  [1987.0, 26.0, 0.0],
#  [1988.0, 25.0, -1.0],
#  [1989.0, 25.0, 0.0],
#  [1999.0, 24.0, -1.0],
#  [2000.0, 24.0, 0.0],
#  [2001.0, 24.0, 0.0],
#  [2002.0, 24.0, 0.0],
#  [2003.0, 24.0, 0.0],
#  [2004.0, 24.0, 0.0],
#  [2005.0, 24.0, 0.0],
#  [2006.0, 24.0, 0.0],
#  [2010.0, 25.0, 1.0],
#  [2011.0, 26.0, 1.0],
#  [2012.0, 26.0, 0.0],
#  [2013.0, 26.0, 0.0],
#  [2015.0, 30.0, 4.0],
#  [2016.0, 30.0, 0.0],
#  [2017.0, 29.0, -1.0]]

# %% [markdown]
# ---

# %% [markdown]
# <a id='q6'></a>
# [Table of Contents](#contents_table)
#
# # Q6. What are the top 5 lowest CO2 Emission Grams/Mile emmisions of cars for each of the following brands: Toyota, Ford, Volkswagen, Nissan, Honda
# * Format: A 5X6 list with the first element of each row being the Make of the cars and the following five values being floats sorted in ascending order. The Makes should appear in order listed in the question starting with Toyota and ending with Honda (see example).
#
# Example answer:
# ```
# [['Toyota', 100.0, 140.0, 140.0, 150.0, 150.0],
#  ['Ford',
#   100.025641025641,
#   200.677633075759575,
#   200.677633075759575,
#   200.677633075759575,
#   200.677633075759575],
#  ['Volkswagen', 139.0, 154.0, 166.5, 166.5, 166.5],
#  ['Nissan', 122.0, 122.0, 122.0, 122.0, 160.0],
#  ['Honda', 100.0, 100.0, 100.0, 100.0, 123.91684618442447]]
# ```
#
# ---

# %%
########## Q6
def brand(s):
    s = str(s)
    # Filtering by brand and CO2 Emission Grams/Mile:
    lco2e = data[s == data['Make']][['Make','CO2 Emission Grams/Mile']]
    # Sort and take TOP 5:
    lco2e.sort_values('CO2 Emission Grams/Mile',inplace=True)
    lco2e = lco2e.iloc[:5]
    return lco2e['CO2 Emission Grams/Mile']

# %%
brands = ['Toyota','Ford','Volkswagen','Nissan','Honda']
lst_q6 = [['Toyota'],['Ford'],['Volkswagen'],['Nissan'],['Honda']]
it = 0
for b in brands:
    x = brand(b).to_list()
    lst_q6[it] = lst_q6[it] + x
    it+=1

# %%
answer_dict['Q6'] = lst_q6
answer_dict['Q6']
# Out:
# [['Toyota', 133.0, 133.0, 133.0, 133.0, 158.0],
#  ['Ford', 112.0, 129.0, 129.0, 129.0, 129.0],
#  ['Volkswagen', 200.0, 200.0, 200.0, 200.0, 261.025641025641],
#  ['Nissan', 249.0, 254.0, 254.5, 254.5, 254.5],
#  ['Honda',
#   130.0,
#   167.67924528301887,
#   167.67924528301887,
#   167.67924528301887,
#   167.67924528301887]]

# %% [markdown]
# ---

# %% [markdown]
# <a id='q7'></a>
# [Table of Contents](#contents_table)
#
# # Q7. Form 7 groups of 5 years to calculat the median of Combined MPG of each group. The first group is from 1984 to 1988, the second from 1989 to 1993 and so on. The last group will have years not appearing in the dataset.
#
# ##### Note: The groups ranges are inclusive on both sides, the first group starts with 1984 and cars from 1984 are included in it.
# ##### Format : A 7X2 list with the first element of each row being a tuple of two integers being the lower and uppper range of the year groups and the esecond element being the median Combined MPG of that group, a float number.
#
# ---

# %%
########## Q7
year_range = 0
g=[0]*7
lst_q7 = [[]*2]*7
for i in range(7):

    g[i] = data[(1984+year_range<=data['Year']) & (1988+year_range>=data['Year'])][['Year','Combined MPG']]
    median = g[i]['Combined MPG'].median()   
    lst_q7[i] = [(1984+year_range,1988+year_range), median]  
    print(lst_q7[i])
    year_range+=5
# Out:
# [(1984, 1988), 19.0]
# [(1989, 1993), 18.0]
# [(1994, 1998), 19.0]
# [(1999, 2003), 19.0]
# [(2004, 2008), 19.0]
# [(2009, 2013), 21.0]
# [(2014, 2018), 22.0]

# %%
answer_dict['Q7'] = lst_q7
answer_dict['Q7']
# Out:
# [[(1984, 1988), 19.0],
#  [(1989, 1993), 18.0],
#  [(1994, 1998), 19.0],
#  [(1999, 2003), 19.0],
#  [(2004, 2008), 19.0],
#  [(2009, 2013), 21.0],
#  [(2014, 2018), 22.0]]

# %% [markdown]
# ---

# %% [markdown]
# <a id='saving_to_pickle'></a>
# [Table of Contents](#contents_table)
#
# # Saving results to Answers dictionary:
#
# ---

# %%
answer_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Mercedes-Benz', 333],
#   ['BMW', 284],
#   ['Chevrolet', 253],
#   ['Ford', 185],
#   ['GMC', 163]],
#  'Q3': ['Regular Gas or Electricity',
#   'Regular Gas and Electricity',
#   'Regular',
#   'Premium or E85',
#   'Premium and Electricity',
#   'Premium Gas or Electricity',
#   'Premium',
#   'Midgrade',
#   'Gasoline or propane',
#   'Gasoline or natural gas',
#   'Gasoline or E85',
#   'Diesel',
#   'CNG'],
#  'Q4': [['Camry CNG', 2001, -3.9316423754756538],
#   ['Camry CNG', 2000, -3.9316423754756538],
#   ['Camry CNG', 1999, -3.932541757118491],
#   ['Cab/Chassis 2WD', 1993, 4.1122558654247925],
#   ['Cab/Chassis 2WD', 1992, 4.1122558654247925],
#   ['Cab/Chassis 2WD', 1992, 3.3791118637260937],
#   ['Cab/Chassis 2WD', 1991, 4.1122558654247925],
#   ['Cab/Chassis 2WD', 1990, 4.1122558654247925],
#   ['Cab/Chassis 2WD', 1989, 4.1122558654247925]],
#  'Q5': [[1986.0, 26.0, 0.0],
#   [1987.0, 26.0, 0.0],
#   [1988.0, 25.0, -1.0],
#   [1989.0, 25.0, 0.0],
#   [1999.0, 24.0, -1.0],
#   [2000.0, 24.0, 0.0],
#   [2001.0, 24.0, 0.0],
#   [2002.0, 24.0, 0.0],
#   [2003.0, 24.0, 0.0],
#   [2004.0, 24.0, 0.0],
#   [2005.0, 24.0, 0.0],
#   [2006.0, 24.0, 0.0],
#   [2010.0, 25.0, 1.0],
#   [2011.0, 26.0, 1.0],
#   [2012.0, 26.0, 0.0],
#   [2013.0, 26.0, 0.0],
#   [2015.0, 30.0, 4.0],
#   [2016.0, 30.0, 0.0],
#   [2017.0, 29.0, -1.0]],
#  'Q6': [['Toyota', 133.0, 133.0, 133.0, 133.0, 158.0],
#   ['Ford', 112.0, 129.0, 129.0, 129.0, 129.0],
#   ['Volkswagen', 200.0, 200.0, 200.0, 200.0, 261.025641025641],
#   ['Nissan', 249.0, 254.0, 254.5, 254.5, 254.5],
#   ['Honda',
#    130.0,
#    167.67924528301887,
#    167.67924528301887,
#    167.67924528301887,
#    167.67924528301887]],
#  'Q7': [[(1984, 1988), 19.0],
#   [(1989, 1993), 18.0],
#   [(1994, 1998), 19.0],
#   [(1999, 2003), 19.0],
#   [(2004, 2008), 19.0],
#   [(2009, 2013), 21.0],
#   [(2014, 2018), 22.0]]}

# %%
import pickle

file_name = "Adrian_Ramos_answers.pkl"
path = "../"

with open(path+file_name, 'wb') as f:
    pickle.dump(answer_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#% Load the saved model:
pickle_dict = pickle.load(open(path+file_name,'rb'))
pickle_dict
# Out:
# {'Q1': 392.7417210857633,
#  'Q2': [['Mercedes-Benz', 333],
#   ['BMW', 284],
#   ['Chevrolet', 253],
#   ['Ford', 185],
#   ['GMC', 163]],
#  'Q3': ['Regular Gas or Electricity',
#   'Regular Gas and Electricity',
#   'Regular',
#   'Premium or E85',
#   'Premium and Electricity',
#   'Premium Gas or Electricity',
#   'Premium',
#   'Midgrade',
#   'Gasoline or propane',
#   'Gasoline or natural gas',
#   'Gasoline or E85',
#   'Diesel',
#   'CNG'],
#  'Q4': [['Camry CNG', 2001, -3.9316423754756538],
#   ['Camry CNG', 2000, -3.9316423754756538],
#   ['Camry CNG', 1999, -3.932541757118491],
#   ['Cab/Chassis 2WD', 1993, 4.1122558654247925],
#   ['Cab/Chassis 2WD', 1992, 4.1122558654247925],
#   ['Cab/Chassis 2WD', 1992, 3.3791118637260937],
#   ['Cab/Chassis 2WD', 1991, 4.1122558654247925],
#   ['Cab/Chassis 2WD', 1990, 4.1122558654247925],
#   ['Cab/Chassis 2WD', 1989, 4.1122558654247925]],
#  'Q5': [[1986.0, 26.0, 0.0],
#   [1987.0, 26.0, 0.0],
#   [1988.0, 25.0, -1.0],
#   [1989.0, 25.0, 0.0],
#   [1999.0, 24.0, -1.0],
#   [2000.0, 24.0, 0.0],
#   [2001.0, 24.0, 0.0],
#   [2002.0, 24.0, 0.0],
#   [2003.0, 24.0, 0.0],
#   [2004.0, 24.0, 0.0],
#   [2005.0, 24.0, 0.0],
#   [2006.0, 24.0, 0.0],
#   [2010.0, 25.0, 1.0],
#   [2011.0, 26.0, 1.0],
#   [2012.0, 26.0, 0.0],
#   [2013.0, 26.0, 0.0],
#   [2015.0, 30.0, 4.0],
#   [2016.0, 30.0, 0.0],
#   [2017.0, 29.0, -1.0]],
#  'Q6': [['Toyota', 133.0, 133.0, 133.0, 133.0, 158.0],
#   ['Ford', 112.0, 129.0, 129.0, 129.0, 129.0],
#   ['Volkswagen', 200.0, 200.0, 200.0, 200.0, 261.025641025641],
#   ['Nissan', 249.0, 254.0, 254.5, 254.5, 254.5],
#   ['Honda',
#    130.0,
#    167.67924528301887,
#    167.67924528301887,
#    167.67924528301887,
#    167.67924528301887]],
#  'Q7': [[(1984, 1988), 19.0],
#   [(1989, 1993), 18.0],
#   [(1994, 1998), 19.0],
#   [(1999, 2003), 19.0],
#   [(2004, 2008), 19.0],
#   [(2009, 2013), 21.0],
#   [(2014, 2018), 22.0]]}

# %% [markdown]
# ---

# %% [markdown]
# <a id='unit_tests'></a>
# [Table of Contents](#contents_table)
#
# # UNIT TESTS.
#
# ---

# %%
import unittest

class TestAnswers(unittest.TestCase):
    def test_if_dict(self):
        self.assertIsInstance(answer_dict, dict)

    def test_keys(self):
        self.assertEqual(list(answer_dict.keys()), ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7'])

    def test_answers_types(self):
        types_values = [type(k) for k in answer_dict.values()]
        answer_types = [float, list, list, list, list, list, list]
        self.assertEqual(types_values, answer_types)

    def test_Q1(self):
        self.assertEqual(type(answer_dict['Q1']), float)

    def test_Q2_dim(self):
        self.assertEqual(np.array(answer_dict['Q2']).shape, (5,2))

    def test_Q2_types(self):
        dtype1 = type(answer_dict['Q2'][0][0])
        dtype2 = type(answer_dict['Q2'][0][1])
        self.assertEqual([dtype1, dtype2], [str, int])

    def test_Q3_types(self):
        q3_types = set([type(item) for item in answer_dict['Q3']])
        self.assertEqual(q3_types, {str})

    def test_Q4_dim(self):
        self.assertEqual(np.array(answer_dict['Q4']).shape, (9,3))

    def test_Q4_types(self):
        dtype1 = type(answer_dict['Q4'][0][0])
        dtype2 = type(answer_dict['Q4'][0][1])
        dtype3 = type(answer_dict['Q4'][0][2])
        self.assertEqual([dtype1, dtype2, dtype3], [str, int, float])

    def test_Q5_dim(self):
        self.assertEqual(np.array(answer_dict['Q5']).shape, (19,3))

    def test_Q5_types(self):
        dtype1 = type(answer_dict['Q5'][0][0])
        dtype2 = type(answer_dict['Q5'][0][1])
        dtype3 = type(answer_dict['Q5'][0][2])
        self.assertEqual([dtype1, dtype2, dtype3], [int, int, float])

    def test_Q5_first_zero(self):
        self.assertEqual(answer_dict['Q5'][0][2], 0)


    def test_Q6_dim(self):
        self.assertEqual(np.array(answer_dict['Q6']).shape, (5,6))

    def test_Q5_types(self):
        dtype1 = type(answer_dict['Q6'][0][0])
        dtype2 = type(answer_dict['Q6'][0][1])
        dtype3 = type(answer_dict['Q6'][0][2])
        dtype4 = type(answer_dict['Q6'][0][3])
        dtype5 = type(answer_dict['Q6'][0][4])
        dtype6 = type(answer_dict['Q6'][0][5])
        self.assertEqual([dtype1, dtype2, dtype3, dtype4, dtype5, dtype6], [str, float, float, float, float, float])

    def test_Q6_check_first_and_last_brand(self):
        first_brand = answer_dict['Q6'][0][0]
        last_brand = answer_dict['Q6'][4][0]

        self.assertEqual([first_brand, last_brand], ["Toyota", "Honda"])

    def test_Q7_dim(self):
        self.assertEqual(np.array(answer_dict['Q7'], dtype=object).shape, (7,2))

    def test_Q7_types(self):
        dtype1 = type(answer_dict['Q7'][0][0])
        dtype2 = type(answer_dict['Q7'][0][1])
        self.assertEqual([dtype1, dtype2], [tuple, float])

unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_Q1 (__main__.TestAnswers) ... ok
# test_Q2_dim (__main__.TestAnswers) ... ok
# test_Q2_types (__main__.TestAnswers) ... ok
# test_Q3_types (__main__.TestAnswers) ... ok
# test_Q4_dim (__main__.TestAnswers) ... ok
# test_Q4_types (__main__.TestAnswers) ... ok
# test_Q5_dim (__main__.TestAnswers) ... ok
# test_Q5_first_zero (__main__.TestAnswers) ... ok
# test_Q5_types (__main__.TestAnswers) ... ok
# test_Q6_check_first_and_last_brand (__main__.TestAnswers) ... ok
# test_Q6_dim (__main__.TestAnswers) ... ok
# test_Q7_dim (__main__.TestAnswers) ... ok
# test_Q7_types (__main__.TestAnswers) ... ok
# test_answers_types (__main__.TestAnswers) ... ok
# test_if_dict (__main__.TestAnswers) ... ok
# test_keys (__main__.TestAnswers) ... ok
#
# ----------------------------------------------------------------------
# Ran 16 tests in 0.080s
#
# OK
